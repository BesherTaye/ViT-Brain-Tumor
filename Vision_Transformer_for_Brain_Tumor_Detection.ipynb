# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import tensorflow as tf
import os
from tensorflow.keras.layers import Dense,Add, Dropout, Resizing,Rescaling,InputLayer,Flatten,LayerNormalization, MultiHeadAttention

from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers,Model
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix,confusion_matrix
from tensorflow.keras.regularizers import L2
from tensorflow.keras.metrics import CategoricalAccuracy, TopKCategoricalAccuracy
from tensorflow.keras.layers import RandomRotation, RandomFlip, RandomContrast

from tensorflow.keras.preprocessing.image import load_img
from functools import partial
import seaborn as sns
from sklearn.model_selection   import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
learning_rate = 0.0001
class_name=['glioma','meningioma','notumor','pituitary']
weight_decay = 0.0001
num_classes=4
batch_size =32
num_epochs = 100
image_size = 256  # We'll resize input images to this size
patch_size = 16  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
Num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
num_layers = 15
Hidden_size=64
mlp_head_units = 1024

# %% [markdown]
# # Data Exploration

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip the downloaded file
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/dataset_1.zip", "r")
zip_ref.extractall()
zip_ref.close()

# %%
train_data='/content/Training'
test_data='/content/Testing'

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
    validation_split=0.2,
    subset='training',
)
val_dataset = tf.keras.utils.image_dataset_from_directory(
    train_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
    validation_split=0.2,  # Use 20% of the data for validation
    subset='validation',
)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.
# Found 1311 files belonging to 4 classes.

# %% [markdown]
# # **Data Visualization**

# %%
plt.figure(figsize=(8, 8))
for images, labels in train_dataset.take(10):
    for i in range(min(16, len(images))):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i] / 255., cmap='gray')
        plt.title(class_name[tf.argmax(labels[i]).numpy()])
        plt.axis("off")

plt.show()

# %%
plt.figure(figsize=(8, 8))
for images, labels in train_dataset.take(10):
    for i in range(min(16, len(images))):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i] / 255., cmap='gray')
        plt.title(class_name[tf.argmax(labels[i]).numpy()])
        plt.axis("off")

plt.show()

# %%
import numpy as np
from PIL import Image

# Load image
image = Image.open('/content/Training/glioma/Tr-glTr_0000.jpg')

# Convert to NumPy array
image_array = np.array(image)

# Get the shape of the image
print(f"Sample Image Shape: {image_array.shape}")
# Out:
# Sample Image Shape: (512, 512, 3)

# %% [markdown]
# # Data Augmentation

# %%
augment_layers = tf.keras.Sequential([
    RandomRotation(factor=(-0.25, 0.2501)),
   RandomFlip("horizontal_and_vertical",seed=42),  # Specify a seed for reproducibility
])

# %%
# Define a custom preprocessing function
def process_data(image, label):
    augmented_image=augment_layers(image)
    resized_image = tf.image.resize(augmented_image, size=(image_size, image_size))
    return resized_image, label

# Apply augmentation and preprocessing to the dataset
training_dataset = (
    train_dataset.
    shuffle(1000)
    .map(partial(process_data),num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
vali_dataset=(
   val_dataset.shuffle(1000)
    .prefetch(tf.data.AUTOTUNE)


)

# %%
input_tensor = next(iter(training_dataset))[0]

# %%
patche=tf.image.extract_patches(images=input_tensor,
                               sizes=[1,patch_size,patch_size,1],
                                strides=[1,patch_size,patch_size,1],
                                rates=[1,1,1,1],
                                 padding='VALID')

# %%
plt.figure(figsize=(12, 12))

batch_size, patch_rows, patch_cols, channels = patche.shape
plt.subplot(1, 2, 1)
plt.imshow(input_tensor[0],cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()
for i in range(patch_rows):
    for j in range(patch_cols):
        ax = plt.subplot(patch_rows, patch_cols, i * patch_cols + j + 1)
        plt.imshow(patche[0, i, j, :].numpy().reshape (patch_size,patch_size, 1),cmap='gray')
        plt.axis("off")

plt.show()

# %% [markdown]
# # ViT MODEL

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, patch_size,Hidden_size):
        super(PatchEncoder, self).__init__(name='patch_encoder')
        self.linear_projection=Dense(Hidden_size)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=Hidden_size
        )

        self.num_patches=num_patches

    def call(self, image):
        batch_size = tf.shape(image)[0]  # Retrieve batch size
        patches=tf.image.extract_patches(images=image,
                                sizes=[1,patch_size,patch_size,1],
                                strides=[1,patch_size,patch_size,1],
                                rates=[1,1,1,1],
                                 padding='VALID'
                                )

        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patches.shape[-1]])
        embedding_input=tf.range(start=0,limit =self.num_patches,delta=1)
        output=self.linear_projection(patches)+ self.position_embedding(embedding_input)
        return output

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, Num_heads,Hidden_size):
        super(TransformerEncoder, self).__init__(name='transformer_encoder')
        self.layer_norm_1=LayerNormalization()
        self.layer_norm_2=LayerNormalization()

        self.multi_head_att=MultiHeadAttention(Num_heads,Hidden_size)

        self.dense_1=Dense(Hidden_size,activation=tf.nn.gelu)
        self.dense_2=Dense(Hidden_size,activation=tf.nn.gelu)


    def call(self, input):
        x=self.layer_norm_1(input)
        x1=self.multi_head_att(x,x)

        x1=Add()([x1,input])
        x2=self.layer_norm_2(x1)
        x2=self.dense_1(x2)
        output=self.dense_1(x2)
        output=Add()([output,x1])

        return output

# %%
class VIT(tf.keras.Model):
    def __init__(self, Num_heads, Hidden_size, num_patches, num_layers, mlp_head_units):
        super(VIT, self).__init__(name='vision_transformer')
        self.num_layers = num_layers
        self.patch_encoder = PatchEncoder(patch_size, Hidden_size)
        self.trans_encoder = [TransformerEncoder(Num_heads, Hidden_size) for _ in range(num_layers)]
        self.flatten = layers.Flatten()
        self.dense_1 = layers.Dense(mlp_head_units, activation='relu')
        self.dense_2 = layers.Dense(mlp_head_units, activation='relu')
        self.dense_3 = layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        x = self.patch_encoder(inputs)  # Get encoded patches
        for i in range(self.num_layers):
            x = self.trans_encoder[i](x)  # Apply transformer encoder layers

        x = self.flatten(x)
        x = self.dense_1(x)
        x = self.dense_2(x)
        output = self.dense_3(x)
        return output

# Create and compile the VIT model
vit = VIT(Num_heads, Hidden_size, num_patches, num_layers, mlp_head_units)

# %% [markdown]
# # Model Training

# %%
loss_funcion=tf.keras.losses.CategoricalCrossentropy(
    from_logits=False,

)

# %%
metrics=[CategoricalAccuracy(name= 'accuracy'),TopKCategoricalAccuracy(k=2,name='top_k_accuracy')]

# %%
vit.compile(
    optimizer=Adam(learning_rate=learning_rate),
                   loss=loss_funcion,
                   metrics=metrics

)

# %%
# Define directory for saving checkpoints
checkpoint_dir = "checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_filepath = os.path.join(checkpoint_dir, "model1_checkpoint.weights.h5")

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
)

# %%
# Train the model
history = vit.fit(
    training_dataset,
    epochs=num_epochs,
    verbose=1,
    validation_data=vali_dataset,
    callbacks=[checkpoint_callback]

)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:393: UserWarning: `build()` was called on layer 'transformer_encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 109s 301ms/step - accuracy: 0.3732 - loss: 68.1307 - top_k_accuracy: 0.6876 - val_accuracy: 0.4685 - val_loss: 5.5104 - val_top_k_accuracy: 0.7601
# Epoch 2/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 151ms/step - accuracy: 0.5402 - loss: 4.4930 - top_k_accuracy: 0.8042 - val_accuracy: 0.6060 - val_loss: 3.8885 - val_top_k_accuracy: 0.8170
# Epoch 3/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.5858 - loss: 2.9981 - top_k_accuracy: 0.8217 - val_accuracy: 0.5998 - val_loss: 2.6013 - val_top_k_accuracy: 0.8319
# Epoch 4/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 28s 172ms/step - accuracy: 0.6061 - loss: 2.2567 - top_k_accuracy: 0.8336 - val_accuracy: 0.6313 - val_loss: 1.9482 - val_top_k_accuracy: 0.8651
# Epoch 5/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 146ms/step - accuracy: 0.6030 - loss: 1.9757 - top_k_accuracy: 0.8501 - val_accuracy: 0.6270 - val_loss: 1.7849 - val_top_k_accuracy: 0.8608
# Epoch 6/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 141ms/step - accuracy: 0.6223 - loss: 1.7460 - top_k_accuracy: 0.8558 - val_accuracy: 0.6261 - val_loss: 1.4177 - val_top_k_accuracy: 0.8722
# Epoch 7/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - accuracy: 0.6612 - loss: 1.3535 - top_k_accuracy: 0.8702 - val_accuracy: 0.6322 - val_loss: 1.2955 - val_top_k_accuracy: 0.8730
# Epoch 8/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 140ms/step - accuracy: 0.6600 - loss: 1.3002 - top_k_accuracy: 0.8769 - val_accuracy: 0.6025 - val_loss: 1.3854 - val_top_k_accuracy: 0.8546
# Epoch 9/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - accuracy: 0.6607 - loss: 1.2474 - top_k_accuracy: 0.8668 - val_accuracy: 0.6865 - val_loss: 0.9981 - val_top_k_accuracy: 0.8940
# Epoch 10/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 143ms/step - accuracy: 0.6778 - loss: 1.0728 - top_k_accuracy: 0.8932 - val_accuracy: 0.6585 - val_loss: 1.1159 - val_top_k_accuracy: 0.8853
# Epoch 11/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 144ms/step - accuracy: 0.6893 - loss: 1.0077 - top_k_accuracy: 0.8972 - val_accuracy: 0.6760 - val_loss: 1.0451 - val_top_k_accuracy: 0.8722
# Epoch 12/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 155ms/step - accuracy: 0.7164 - loss: 0.9395 - top_k_accuracy: 0.9060 - val_accuracy: 0.6900 - val_loss: 0.9613 - val_top_k_accuracy: 0.9028
# Epoch 13/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - accuracy: 0.7125 - loss: 0.9254 - top_k_accuracy: 0.9190 - val_accuracy: 0.7128 - val_loss: 0.9051 - val_top_k_accuracy: 0.9177
# Epoch 14/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 157ms/step - accuracy: 0.7393 - loss: 0.8522 - top_k_accuracy: 0.9204 - val_accuracy: 0.7382 - val_loss: 0.8518 - val_top_k_accuracy: 0.9282
# Epoch 15/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.7464 - loss: 0.8468 - top_k_accuracy: 0.9242 - val_accuracy: 0.7469 - val_loss: 0.8739 - val_top_k_accuracy: 0.9203
# Epoch 16/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 144ms/step - accuracy: 0.7555 - loss: 0.8267 - top_k_accuracy: 0.9258 - val_accuracy: 0.7189 - val_loss: 0.9917 - val_top_k_accuracy: 0.8932
# Epoch 17/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.7478 - loss: 0.8202 - top_k_accuracy: 0.9260 - val_accuracy: 0.6550 - val_loss: 1.0344 - val_top_k_accuracy: 0.9256
# Epoch 18/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 46s 180ms/step - accuracy: 0.7553 - loss: 0.8262 - top_k_accuracy: 0.9246 - val_accuracy: 0.7933 - val_loss: 0.8044 - val_top_k_accuracy: 0.9326
# Epoch 19/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.7606 - loss: 0.8003 - top_k_accuracy: 0.9323 - val_accuracy: 0.7907 - val_loss: 0.6773 - val_top_k_accuracy: 0.9553
# Epoch 20/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 141ms/step - accuracy: 0.7902 - loss: 0.7266 - top_k_accuracy: 0.9412 - val_accuracy: 0.7855 - val_loss: 0.7308 - val_top_k_accuracy: 0.9405
# Epoch 21/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 184ms/step - accuracy: 0.7946 - loss: 0.6376 - top_k_accuracy: 0.9493 - val_accuracy: 0.7942 - val_loss: 0.7870 - val_top_k_accuracy: 0.9483
# Epoch 22/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 36s 139ms/step - accuracy: 0.7822 - loss: 0.6799 - top_k_accuracy: 0.9476 - val_accuracy: 0.7557 - val_loss: 0.7298 - val_top_k_accuracy: 0.9431
# Epoch 23/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 27s 167ms/step - accuracy: 0.7903 - loss: 0.7248 - top_k_accuracy: 0.9432 - val_accuracy: 0.8179 - val_loss: 0.6081 - val_top_k_accuracy: 0.9623
# Epoch 24/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 38s 143ms/step - accuracy: 0.8100 - loss: 0.5919 - top_k_accuracy: 0.9569 - val_accuracy: 0.7644 - val_loss: 0.6780 - val_top_k_accuracy: 0.9422
# Epoch 25/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 140ms/step - accuracy: 0.7928 - loss: 0.6518 - top_k_accuracy: 0.9466 - val_accuracy: 0.8117 - val_loss: 0.5811 - val_top_k_accuracy: 0.9737
# Epoch 26/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 143ms/step - accuracy: 0
100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 144ms/step - accuracy: 0.8572 - loss: 0.4721 - top_k_accuracy: 0.9718 - val_accuracy: 0.7916 - val_loss: 0.6696 - val_top_k_accuracy: 0.9737
# Epoch 44/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.8418 - loss: 0.4761 - top_k_accuracy: 0.9726 - val_accuracy: 0.8363 - val_loss: 0.5105 - val_top_k_accuracy: 0.9764
# Epoch 45/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.8636 - loss: 0.4326 - top_k_accuracy: 0.9771 - val_accuracy: 0.8450 - val_loss: 0.6073 - val_top_k_accuracy: 0.9755
# Epoch 46/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - accuracy: 0.8702 - loss: 0.3832 - top_k_accuracy: 0.9788 - val_accuracy: 0.8485 - val_loss: 0.5555 - val_top_k_accuracy: 0.9685
# Epoch 47/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 144ms/step - accuracy: 0.8672 - loss: 0.4054 - top_k_accuracy: 0.9809 - val_accuracy: 0.8380 - val_loss: 0.6589 - val_top_k_accuracy: 0.9746
# Epoch 48/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.8564 - loss: 0.4568 - top_k_accuracy: 0.9763 - val_accuracy: 0.8292 - val_loss: 0.5842 - val_top_k_accuracy: 0.9711
# Epoch 49/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.8650 - loss: 0.4204 - top_k_accuracy: 0.9772 - val_accuracy: 0.8555 - val_loss: 0.5968 - val_top_k_accuracy: 0.9711
# Epoch 50/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 150ms/step - accuracy: 0.8597 - loss: 0.4278 - top_k_accuracy: 0.9775 - val_accuracy: 0.8599 - val_loss: 0.4735 - val_top_k_accuracy: 0.9825
# Epoch 51/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 144ms/step - accuracy: 0.8677 - loss: 0.4138 - top_k_accuracy: 0.9830 - val_accuracy: 0.8590 - val_loss: 0.5558 - val_top_k_accuracy: 0.9834
# Epoch 52/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 140ms/step - accuracy: 0.8770 - loss: 0.3985 - top_k_accuracy: 0.9850 - val_accuracy: 0.8494 - val_loss: 0.4941 - val_top_k_accuracy: 0.9807
# Epoch 53/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 143ms/step - accuracy: 0.8627 - loss: 0.4326 - top_k_accuracy: 0.9790 - val_accuracy: 0.8450 - val_loss: 0.5306 - val_top_k_accuracy: 0.9746
# Epoch 54/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.8723 - loss: 0.3682 - top_k_accuracy: 0.9828 - val_accuracy: 0.8424 - val_loss: 0.4890 - val_top_k_accuracy: 0.9694
# Epoch 55/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 45s 172ms/step - accuracy: 0.8776 - loss: 0.3860 - top_k_accuracy: 0.9788 - val_accuracy: 0.8704 - val_loss: 0.4424 - val_top_k_accuracy: 0.9764
# Epoch 56/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.8622 - loss: 0.4525 - top_k_accuracy: 0.9776 - val_accuracy: 0.8345 - val_loss: 0.4852 - val_top_k_accuracy: 0.9755
# Epoch 57/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.8708 - loss: 0.4158 - top_k_accuracy: 0.9808 - val_accuracy: 0.8555 - val_loss: 0.5091 - val_top_k_accuracy: 0.9807
# Epoch 58/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.8951 - loss: 0.3489 - top_k_accuracy: 0.9824 - val_accuracy: 0.8862 - val_loss: 0.4080 - val_top_k_accuracy: 0.9816
# Epoch 59/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 142ms/step - accuracy: 0.8833 - loss: 0.3627 - top_k_accuracy: 0.9857 - val_accuracy: 0.8266 - val_loss: 0.7430 - val_top_k_accuracy: 0.9650
# Epoch 60/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s
100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - accuracy: 0.8861 - loss: 0.3285 - top_k_accuracy: 0.9838 - val_accuracy: 0.8713 - val_loss: 0.3863 - val_top_k_accuracy: 0.9851
# Epoch 78/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 145ms/step - accuracy: 0.8950 - loss: 0.3077 - top_k_accuracy: 0.9848 - val_accuracy: 0.8862 - val_loss: 0.3909 - val_top_k_accuracy: 0.9825
# Epoch 79/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 47s 185ms/step - accuracy: 0.9118 - loss: 0.2570 - top_k_accuracy: 0.9896 - val_accuracy: 0.8897 - val_loss: 0.4011 - val_top_k_accuracy: 0.9904
# Epoch 80/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 142ms/step - accuracy: 0.9024 - loss: 0.2782 - top_k_accuracy: 0.9905 - val_accuracy: 0.8511 - val_loss: 0.4503 - val_top_k_accuracy: 0.9764
# Epoch 81/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - accuracy: 0.9011 - loss: 0.2971 - top_k_accuracy: 0.9863 - val_accuracy: 0.8748 - val_loss: 0.4714 - val_top_k_accuracy: 0.9842
# Epoch 82/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.9073 - loss: 0.2835 - top_k_accuracy: 0.9873 - val_accuracy: 0.8800 - val_loss: 0.5002 - val_top_k_accuracy: 0.9886
# Epoch 83/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 143ms/step - accuracy: 0.9130 - loss: 0.3025 - top_k_accuracy: 0.9884 - val_accuracy: 0.8748 - val_loss: 0.5050 - val_top_k_accuracy: 0.9877
# Epoch 84/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 141ms/step - accuracy: 0.8998 - loss: 0.3062 - top_k_accuracy: 0.9897 - val_accuracy: 0.8651 - val_loss: 0.4676 - val_top_k_accuracy: 0.9860
# Epoch 85/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 140ms/step - accuracy: 0.8979 - loss: 0.3078 - top_k_accuracy: 0.9904 - val_accuracy: 0.8809 - val_loss: 0.4376 - val_top_k_accuracy: 0.9895
# Epoch 86/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 24s 142ms/step - accuracy: 0.9158 - loss: 0.2341 - top_k_accuracy: 0.9929 - val_accuracy: 0.8792 - val_loss: 0.4624 - val_top_k_accuracy: 0.9869
# Epoch 87/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 143ms/step - accuracy: 0.9044 - loss: 0.2970 - top_k_accuracy: 0.9853 - val_accuracy: 0.8520 - val_loss: 0.4735 - val_top_k_accuracy: 0.9842
# Epoch 88/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 139ms/step - accuracy: 0.9023 - loss: 0.2833 - top_k_accuracy: 0.9927 - val_accuracy: 0.8485 - val_loss: 0.4531 - val_top_k_accuracy: 0.9869
# Epoch 89/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 141ms/step - accuracy: 0.9014 - loss: 0.2766 - top_k_accuracy: 0.9888 - val_accuracy: 0.8704 - val_loss: 0.4453 - val_top_k_accuracy: 0.9842
# Epoch 90/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 142ms/step - accuracy: 0.9030 - loss: 0.2729 - top_k_accuracy: 0.9901 - val_accuracy: 0.8827 - val_loss: 0.5131 - val_top_k_accuracy: 0.9886
# Epoch 91/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 139ms/step - accuracy: 0.9074 - loss: 0.2902 - top_k_accuracy: 0.9836 - val_accuracy: 0.8678 - val_loss: 0.4170 - val_top_k_accuracy: 0.9781
# Epoch 92/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9077 - loss: 0.2807 - top_k_accuracy: 0.9934 - val_accuracy: 0.8967 - val_loss: 0.4209 - val_top_k_accuracy: 0.9851
# Epoch 93/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 144ms/step - accuracy: 0.9082 - loss: 0.2868 - top_k_accuracy: 0.9875 - val_accuracy: 0.8608 - val_loss: 0.5174 - val_top_k_accuracy: 0.9834
# Epoch 94/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 140ms/step - accuracy: 0.9031 - loss: 0.2752 - top_k_accuracy: 0.9896 - val_accuracy: 0.8905 - val_loss: 0.4306 - val_top_k_accuracy: 0.9860
# Epoch 95/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 144ms/step - accuracy: 0.9181 - loss: 0.2458 - top_k_accuracy: 0.9931 - val_accuracy: 0.8932 - val_loss: 0.3950 - val_top_k_accuracy: 0.9869
# Epoch 96/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 143ms/step - accuracy: 0.9202 - loss: 0.2564 - top_k_accuracy: 0.9940 - val_accuracy: 0.8809 - val_loss: 0.4385 - val_top_k_accuracy: 0.9860
# Epoch 97/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 156ms/step - accuracy: 0.9213 - loss: 0.2395 - top_k_accuracy: 0.9913 - val_accuracy: 0.9002 - val_loss: 0.3208 - val_top_k_accuracy: 0.9895
# Epoch 98/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 144ms/step - accuracy: 0.9167 - loss: 0.2423 - top_k_accuracy: 0.9894 - val_accuracy: 0.8879 - val_loss: 0.3526 - val_top_k_accuracy: 0.9921
# Epoch 99/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9189 - loss: 0.2424 - top_k_accuracy: 0.9907 - val_accuracy: 0.8783 - val_loss: 0.4552 - val_top_k_accuracy: 0.9869
# Epoch 100/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 147ms/step - accuracy: 0.9176 - loss: 0.2423 - top_k_accuracy: 0.9928 - val_accuracy: 0.8555 - val_loss: 0.5126 - val_top_k_accuracy: 0.9886

# %%
vit.summary()
# Out:
# Model: "vision_transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ patch_encoder (PatchEncoder)         │ ?                           │          32,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ transformer_encoder                  │ ?                           │          70,784 │
# │ (TransformerEncoder)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 16384)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 1024)                │      16,778,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 4)                   │           4,100 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,779,598 (216.60 MB)
#  Trainable params: 18,926,532 (72.20 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 37,853,066 (144.40 MB)

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.grid()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Prediction

# %%
pred = vit.predict(test_dataset)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step

# %%
vit.evaluate(test_dataset)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.8636 - loss: 0.4794 - top_k_accuracy: 0.9857
# [0.46999627351760864, 0.8749046325683594, 0.9870327711105347]

# %%
predicted=[]
labels=[]
for im, label in test_dataset:
    predicted.append(vit(im))
    labels.append(label.numpy())

# %%
pred= np.concatenate([np.argmax(predicted[:-1],axis=-1).flatten(),np.argmax(predicted[-1],axis=-1).flatten()])
lab= np.concatenate([np.argmax(labels[:-1],axis=-1).flatten(),np.argmax(labels[-1],axis=-1).flatten()])

# %%
plt.figure(figsize=(12,12))
for   images,labels in  test_dataset.take(10):
  for i   in range(16):
   ax=plt.subplot(4,4,i+1)

   plt.imshow(images[i]/255.)
   plt.title("True Label :"+ class_name[tf.argmax(labels[i],axis=0).numpy()] + "\n" + "Predicted Label  : " + class_name[tf.argmax(vit(tf.expand_dims(images[i],axis=0)),axis= -1).numpy()[0]])
   plt.axis("off")

# %% [markdown]
# # Confusion Matrix

# %%
cm=confusion_matrix(lab,pred)
print(cm)
plt.figure(figsize=(8,8))
sns.heatmap(cm,annot=True)
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel("Predicted")
# Out:
# [[271  27   0   2]
#  [ 51 197  28  30]
#  [  0  11 393   1]
#  [  8   6   0 286]]
# Text(0.5, 58.7222222222222, 'Predicted')

# %% [markdown]
# # ROC Curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.utils import to_categorical

# Define class names
class_name = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary']

# Get the predicted probabilities instead of class labels
predicted_probs = np.concatenate([pred.numpy() for pred in predicted])

lab_one_hot = to_categorical(lab, num_classes=len(class_name))

# Plot ROC Curve for each class
plt.figure(figsize=(8, 6))
for i in range(len(class_name)):
    fpr, tpr, _ = roc_curve(lab_one_hot[:, i], predicted_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_name[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random guessing
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()
